# %% [markdown]
# ### 关于report里的一些结果复现
#
# 复现2-3-2: 更改下面运行的train()的参数、更改train的SGD里的size来实现BGD，SGD和Mini-Batch
#
# 复现2-3-3: 更改DNN_HIDDEN_UNITS_DEFAULT、MAX_EPOCHS_DEFAULT
#
# 复现2-3-4: 更改model.py里Linear类的init方法
#
# 复现2-3-5: 更改model.py的 LEARNING_RATE_DEFAULT

# %%
import numpy as np
import torch
import math
from sklearn import datasets
import matplotlib.pyplot as plt

from mlp_numpy import MLP
import train_mlp_numpy
from modules import *

# %% [markdown]
# 注意：learning rate 要在model.py里的 LEARNING_RATE_DEFAULT 改，改这里的 LEARNING_RATE_DEFAULT 没有用

# %%
# Default constants
DNN_HIDDEN_UNITS_DEFAULT = '20'
LEARNING_RATE_DEFAULT = 0.01
MAX_EPOCHS_DEFAULT = 1500
EVAL_FREQ_DEFAULT = 10

# %%
x, y = datasets.make_moons(n_samples=1000, noise=0.08, shuffle=True, random_state=None)
x_input = np.expand_dims(x, axis=1)
y_onehot = np.eye(2)[y]
y_onehot = np.expand_dims(y_onehot, axis=1)

x_input_train = x_input[:800,:,:]
y_onehot_train = y_onehot[:800,:]
x_input_test = x_input[800:,:,:]
y_onehot_test = y_onehot[800:,:]

# %%
plt.scatter(x[:,0], x[:,1], c=y)

# %%
hidden_array = DNN_HIDDEN_UNITS_DEFAULT.split(",")
model = MLP(2, hidden_array, 2)

# %%
def accuracy(predictions, targets):
    total = predictions.shape[0]
    predictions = np.where(predictions > 0.5, 1, 0)
    acc_cnt = np.sum(predictions * targets)
    return acc_cnt / total

# %%
epoch_set = []
loss_set = []
acc_set = []
acc_train = 0.
acc_test = 0.
acc_test_set = []

# %% [markdown]
# 这个train()和train_mlp_numpy.py中的一样
#
# 使用 mini-batch：修改SGD中的 idxs = np.random.randint(0, x_input_train.shape[0] , size=1) 中的size

# %%
def train(para):
    if para == 'BGD':
        for turn in range(MAX_EPOCHS_DEFAULT):
            pre = model.forward(x_input_train)
            _, loss = CrossEntropy().forward(pre, y_onehot_train)
            loss_avg = np.mean(loss, axis=0)[0]
            acc_train = accuracy(pre, y_onehot_train)
            dout = CrossEntropy().backward(pre, y_onehot_train)
            model.backward(dout)
            if turn > 0 and turn % EVAL_FREQ_DEFAULT == 0:
                pre_test = model.forward(x_input_test)
                acc_test = accuracy(pre_test, y_onehot_test)
                
                epoch_set.append(turn)
                loss_set.append(loss_avg)
                acc_set.append(acc_train)
                acc_test_set.append(acc_test)
                print("The ", turn, " BGD training turn, loss is: ", loss_avg, "accuracy is: ", acc_train)
                print("train accuracy: ", acc_set[-1], "test accuracy: ", acc_test)
    if para == 'SGD':
        for turn in range(MAX_EPOCHS_DEFAULT):
            idxs = np.random.randint(0, x_input_train.shape[0] , size=1)
            tmp_X = x_input_train.take(idxs,axis=0)
            tmp_Y = y_onehot_train.take(idxs,axis=0)
            
            pre = model.forward(tmp_X)
            _, loss = CrossEntropy().forward(pre, tmp_Y)
            loss_avg = np.mean(loss, axis=0)[0]
            acc_train = accuracy(pre, tmp_Y)
            dout = CrossEntropy().backward(pre, tmp_Y)
            model.backward(dout)
            if turn > 0 and turn % EVAL_FREQ_DEFAULT == 0:
                pre_test = model.forward(x_input_test)
                acc_test = accuracy(pre_test, y_onehot_test)
                
                epoch_set.append(turn)
                loss_set.append(loss_avg)
                acc_set.append(acc_train)
                acc_test_set.append(acc_test)
                print("The ", turn, " SGD training turn, loss is: ", loss_avg, "accuracy is: ", acc_train)
                print("train accuracy: ", acc_set[-1], "test accuracy: ", acc_test)

# %% [markdown]
# ### 使用BDG：train("BDG") 使用SDG：train("SDG")

# %%
train("BGD")
# Out:
# The  10  BGD training turn, loss is:  0.6931385517349051 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  20  BGD training turn, loss is:  0.6931314778515918 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  30  BGD training turn, loss is:  0.6931250503514693 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  40  BGD training turn, loss is:  0.6931192174373974 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  50  BGD training turn, loss is:  0.6931139163117092 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  60  BGD training turn, loss is:  0.6931090844453834 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  70  BGD training turn, loss is:  0.6931046733496398 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  80  BGD training turn, loss is:  0.6931006421017721 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  90  BGD training turn, loss is:  0.6930969519275209 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  100  BGD training turn, loss is:  0.6930935664302915 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  110  BGD training turn, loss is:  0.6930904528254969 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  120  BGD training turn, loss is:  0.6930875826322128 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  130  BGD training turn, loss is:  0.6930849302317984 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  140  BGD training turn, loss is:  0.6930824708823369 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  150  BGD training turn, loss is:  0.6930801824641116 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  160  BGD training turn, loss is:  0.6930780442289278 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  170  BGD training turn, loss is:  0.6930760375838935 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  180  BGD training turn, loss is:  0.6930741457948324 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  190  BGD training turn, loss is:  0.6930723535184093 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  200  BGD training turn, loss is:  0.6930706453400883 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  210  BGD training turn, loss is:  0.693069007491317 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  220  BGD training turn, loss is:  0.6930674266310478 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  230  BGD training turn, loss is:  0.6930658916540716 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  240  BGD training turn, loss is:  0.6930643909164462 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  250  BGD training turn, loss is:  0.6930629137408735 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  260  BGD training turn, loss is:  0.693061449505666 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  270  BGD training turn, loss is:  0.6930599886986657 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  280  BGD training turn, loss is:  0.6930585227451155 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  290  BGD training turn, loss is:  0.6930570423463266 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  300  BGD training turn, loss is:  0.6930555385458333 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  310  BGD training turn, loss is:  0.6930540028069635 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  320  BGD training turn, loss is:  0.693052426570827 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  330  BGD training turn, loss is:  0.6930508011359126 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  340  BGD training turn, loss is:  0.6930491181268889 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  350  BGD training turn, loss is:  0.693047369036707 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  360  BGD training turn, loss is:  0.6930455446221414 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  370  BGD training turn, loss is:  0.6930436372474196 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  380  BGD training turn, loss is:  0.6930416370481015 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  390  BGD training turn, loss is:  0.6930395348202617 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  400  BGD training turn, loss is:  0.6930373207416014 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  410  BGD training turn, loss is:  0.6930349856579716 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  420  BGD training turn, loss is:  0.6930325179444009 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  430  BGD training turn, loss is:  0.6930299072159687 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  440  BGD training turn, loss is:  0.6930271406369968 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  450  BGD training turn, loss is:  0.6930242068885937 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  460  BGD training turn, loss is:  0.6930210933363898 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  470  BGD training turn, loss is:  0.6930177857022412 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  480  BGD training turn, loss is:  0.6930142675470397 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  490  BGD training turn, loss is:  0.6930105247114627 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  500  BGD training turn, loss is:  0.6930065415673048 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  510  BGD training turn, loss is:  0.693002301463997 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  520  BGD training turn, loss is:  0.692997786912658 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  530  BGD training turn, loss is:  0.6929929798923409 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  540  BGD training turn, loss is:  0.692987860393167 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  550  BGD training turn, loss is:  0.6929824043554277 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  560  BGD training turn, loss is:  0.692976589590832 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  570  BGD training turn, loss is:  0.6929703942666794 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  580  BGD training turn, loss is:  0.6929637927572133 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  590  BGD training turn, loss is:  0.6929567577396091 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  600  BGD training turn, loss is:  0.6929492612320384 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  610  BGD training turn, loss is:  0.6929412733319787 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  620  BGD training turn, loss is:  0.6929327552248175 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  630  BGD training turn, loss is:  0.6929236683315733 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  640  BGD training turn, loss is:  0.6929139762240359 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  650  BGD training turn, loss is:  0.6929036395342857 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  660  BGD training turn, loss is:  0.6928926158055623 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  670  BGD training turn, loss is:  0.6928808583785708 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  680  BGD training turn, loss is:  0.6928683136364142 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  690  BGD training turn, loss is:  0.6928549294416154 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  700  BGD training turn, loss is:  0.6928406491615224 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  710  BGD training turn, loss is:  0.6928254202920506 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  720  BGD training turn, loss is:  0.6928091791900367 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  730  BGD training turn, loss is:  0.692791858612154 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  740  BGD training turn, loss is:  0.6927733830834962 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  750  BGD training turn, loss is:  0.6927536738823844 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  760  BGD training turn, loss is:  0.6927326588246535 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  770  BGD training turn, loss is:  0.6927102465425052 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  780  BGD training turn, loss is:  0.6926863415378005 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  790  BGD training turn, loss is:  0.6926608533066285 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  800  BGD training turn, loss is:  0.6926336765693768 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  810  BGD training turn, loss is:  0.6926046933181972 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  820  BGD training turn, loss is:  0.6925737893252305 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  830  BGD training turn, loss is:  0.6925408386466106 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  840  BGD training turn, loss is:  0.6925057033909892 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  850  BGD training turn, loss is:  0.6924682335278177 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  860  BGD training turn, loss is:  0.6924282760507873 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  870  BGD training turn, loss is:  0.6923856614986965 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  880  BGD training turn, loss is:  0.6923402160338874 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  890  BGD training turn, loss is:  0.6922917513374668 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  900  BGD training turn, loss is:  0.6922400653653656 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  910  BGD training turn, loss is:  0.6921849445993365 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  920  BGD training turn, loss is:  0.6921261601233055 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  930  BGD training turn, loss is:  0.692063469536898 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  940  BGD training turn, loss is:  0.6919966130275483 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  950  BGD training turn, loss is:  0.6919253157517836 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  960  BGD training turn, loss is:  0.6918492832981556 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  970  BGD training turn, loss is:  0.6917682040843487 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  980  BGD training turn, loss is:  0.6916817439106357 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  990  BGD training turn, loss is:  0.6915895477472992 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1000  BGD training turn, loss is:  0.6914912376099924 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1010  BGD training turn, loss is:  0.6913864111229008 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1020  BGD training turn, loss is:  0.6912746401941535 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1030  BGD training turn, loss is:  0.6911554691099792 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1040  BGD training turn, loss is:  0.6910284129503999 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1050  BGD training turn, loss is:  0.690892956157874 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1060  BGD training turn, loss is:  0.6907485504774836 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1070  BGD training turn, loss is:  0.6905946122442103 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1080  BGD training turn, loss is:  0.6904305214257406 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1090  BGD training turn, loss is:  0.6902556190333716 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1100  BGD training turn, loss is:  0.6900692048606117 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1110  BGD training turn, loss is:  0.6898705349240362 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1120  BGD training turn, loss is:  0.6896588195308386 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1130  BGD training turn, loss is:  0.6894332209384589 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1140  BGD training turn, loss is:  0.6891928499560452 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1150  BGD training turn, loss is:  0.6889367637377812 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1160  BGD training turn, loss is:  0.688663962374697 accuracy is:  0.50625
# train accuracy:  0.50625 test accuracy:  0.475
# The  1170  BGD training turn, loss is:  0.6883733869667336 accuracy is:  0.5075
# train accuracy:  0.5075 test accuracy:  0.475
# The  1180  BGD training turn, loss is:  0.688063915810501 accuracy is:  0.53125
# train accuracy:  0.53125 test accuracy:  0.51
# The  1190  BGD training turn, loss is:  0.6877343618991841 accuracy is:  0.6025
# train accuracy:  0.6025 test accuracy:  0.585
# The  1200  BGD training turn, loss is:  0.6873834695464971 accuracy is:  0.6775
# train accuracy:  0.6775 test accuracy:  0.655
# The  1210  BGD training turn, loss is:  0.6870099116732211 accuracy is:  0.71625
# train accuracy:  0.71625 test accuracy:  0.7
# The  1220  BGD training turn, loss is:  0.6866122863547457 accuracy is:  0.74125
# train accuracy:  0.74125 test accuracy:  0.73
# The  1230  BGD training turn, loss is:  0.686189113545934 accuracy is:  0.76
# train accuracy:  0.76 test accuracy:  0.75
# The  1240  BGD training turn, loss is:  0.6857388326652759 accuracy is:  0.77875
# train accuracy:  0.77875 test accuracy:  0.78
# The  1250  BGD training turn, loss is:  0.6852597996445289 accuracy is:  0.7925
# train accuracy:  0.7925 test accuracy:  0.79
# The  1260  BGD training turn, loss is:  0.6847502825287114 accuracy is:  0.80125
# train accuracy:  0.80125 test accuracy:  0.8
# The  1270  BGD training turn, loss is:  0.6842084596997597 accuracy is:  0.80375
# train accuracy:  0.80375 test accuracy:  0.795
# The  1280  BGD training turn, loss is:  0.6836324171249651 accuracy is:  0.81375
# train accuracy:  0.81375 test accuracy:  0.79
# The  1290  BGD training turn, loss is:  0.6830201458552214 accuracy is:  0.8125
# train accuracy:  0.8125 test accuracy:  0.795
# The  1300  BGD training turn, loss is:  0.6823695403978146 accuracy is:  0.81125
# train accuracy:  0.81125 test accuracy:  0.795
# The  1310  BGD training turn, loss is:  0.6816783963988706 accuracy is:  0.81125
# train accuracy:  0.81125 test accuracy:  0.8
# The  1320  BGD training turn, loss is:  0.6809444101914679 accuracy is:  0.8075
# train accuracy:  0.8075 test accuracy:  0.795
# The  1330  BGD training turn, loss is:  0.6801651768233574 accuracy is:  0.79875
# train accuracy:  0.79875 test accuracy:  0.8
# The  1340  BGD training turn, loss is:  0.6793381892906075 accuracy is:  0.8025
# train accuracy:  0.8025 test accuracy:  0.8
# The  1350  BGD training turn, loss is:  0.6784608402305963 accuracy is:  0.805
# train accuracy:  0.805 test accuracy:  0.8
# The  1360  BGD training turn, loss is:  0.677530422793505 accuracy is:  0.80875
# train accuracy:  0.80875 test accuracy:  0.795
# The  1370  BGD training turn, loss is:  0.6765441325163777 accuracy is:  0.80875
# train accuracy:  0.80875 test accuracy:  0.795
# The  1380  BGD training turn, loss is:  0.6754990715067077 accuracy is:  0.80875
# train accuracy:  0.80875 test accuracy:  0.78
# The  1390  BGD training turn, loss is:  0.6743922480630107 accuracy is:  0.80625
# train accuracy:  0.80625 test accuracy:  0.78
# The  1400  BGD training turn, loss is:  0.6732205984110258 accuracy is:  0.8075
# train accuracy:  0.8075 test accuracy:  0.78
# The  1410  BGD training turn, loss is:  0.6719809747027071 accuracy is:  0.80875
# train accuracy:  0.80875 test accuracy:  0.795
# The  1420  BGD training turn, loss is:  0.6706701459464424 accuracy is:  0.8125
# train accuracy:  0.8125 test accuracy:  0.8
# The  1430  BGD training turn, loss is:  0.6692848274460501 accuracy is:  0.81125
# train accuracy:  0.81125 test accuracy:  0.805
# The  1440  BGD training turn, loss is:  0.6678216852792274 accuracy is:  0.8075
# train accuracy:  0.8075 test accuracy:  0.81
# The  1450  BGD training turn, loss is:  0.6662773480992444 accuracy is:  0.80375
# train accuracy:  0.80375 test accuracy:  0.81
# The  1460  BGD training turn, loss is:  0.664648424040326 accuracy is:  0.7975
# train accuracy:  0.7975 test accuracy:  0.81
# The  1470  BGD training turn, loss is:  0.6629315300015509 accuracy is:  0.8
# train accuracy:  0.8 test accuracy:  0.81
# The  1480  BGD training turn, loss is:  0.6611232913640798 accuracy is:  0.79875
# train accuracy:  0.79875 test accuracy:  0.81
# The  1490  BGD training turn, loss is:  0.6592203559769219 accuracy is:  0.79875
# train accuracy:  0.79875 test accuracy:  0.81

# %%
plt.plot(epoch_set, loss_set, linewidth=1, color="blue",label="loss")
plt.plot(epoch_set, acc_set, linewidth=1, color="orange",label="acc_train")
plt.plot(epoch_set, acc_test_set, linewidth=1, color="red",label="acc_test")
plt.legend()

# %% [markdown]
# 最后的test accuracy rate

# %%
pre = model.forward(x_input_test)
acc_test = accuracy(pre, y_onehot_test)
print("train accuracy: ", acc_set[-1], "test accuracy: ", acc_test)
# Out:
# train accuracy:  0.79875 test accuracy:  0.805
